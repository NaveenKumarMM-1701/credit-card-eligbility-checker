# %% [markdown]
# ### Importing Packages

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the Data

# %%
df1 = pd.read_csv("payment_data.csv")
df1
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date
# 0        16500.0  04/12/2016          0.0              NaN         NaN
# 1            NaN  04/12/2016     588720.0         491100.0         NaN
# 2            NaN  04/12/2016     840000.0         700500.0  22/04/2016
# 3        37400.0  03/12/2016       8425.2           7520.0  25/04/2016
# 4            NaN  03/12/2016      15147.6              NaN  26/04/2016
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaN          0.0              NaN         NaN
# 8246         NaN         NaN          0.0              NaN         NaN
# 8247         NaN         NaN      20654.4          33315.0         NaN
# 8248         NaN         NaN          0.0              NaN         NaN
# 8249         NaN         NaN     240000.0         200500.0         NaN
#
# [8250 rows x 12 columns]

# %%
df = pd.read_csv("customer_data.csv")
df
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2         0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3         1  58995168      7  1335.5      1  151000.0      2     11      5
# 4         0  54987320      7     NaN      2   59000.0      2     11      5
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 1120      0  58988196      5  1289.0      1  173000.0      2     15      5
# 1121      0  58987926      5     NaN      2   50000.0      2     15      5
# 1122      0  58995381      7  1220.0      3   76000.0      2     11      2
# 1123      0  58998054      4  1250.0      3  137000.0      2      8      5
# 1124      0  54989781      4  1415.0      3   93000.0      2      8      5
#
#       fea_8  fea_9  fea_10      fea_11
# 0       109      5  151300  244.948974
# 1       100      3  341759  207.173840
# 2       101      5   72001    1.000000
# 3       110      3   60084    1.000000
# 4       108      4  450081  197.403141
# ...     ...    ...     ...         ...
# 1120    112      3  350702  200.000000
# 1121    108      4  450000  169.000000
# 1122     90      5   71002    1.000000
# 1123     90      5   72000    1.000000
# 1124    113      4  151300  273.861279
#
# [1125 rows x 13 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   object
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 773.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1125 non-null   int64
#  1   id      1125 non-null   int64
#  2   fea_1   1125 non-null   int64
#  3   fea_2   976 non-null    float64
#  4   fea_3   1125 non-null   int64
#  5   fea_4   1125 non-null   float64
#  6   fea_5   1125 non-null   int64
#  7   fea_6   1125 non-null   int64
#  8   fea_7   1125 non-null   int64
#  9   fea_8   1125 non-null   int64
#  10  fea_9   1125 non-null   int64
#  11  fea_10  1125 non-null   int64
#  12  fea_11  1125 non-null   float64
# dtypes: float64(3), int64(10)
# memory usage: 114.4 KB

# %%
for i in df.columns:
    values = df[i].value_counts
    print(values)
    print()
    print("**********************************")
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1120    0
# 1121    0
# 1122    0
# 1123    0
# 1124    0
# Name: label, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       54982665
# 1       59004779
# 2       58990862
# 3       58995168
# 4       54987320
#           ...
# 1120    58988196
# 1121    58987926
# 1122    58995381
# 1123    58998054
# 1124    54989781
# Name: id, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       5
# 1       4
# 2       7
# 3       7
# 4       7
#        ..
# 1120    5
# 1121    5
# 1122    7
# 1123    4
# 1124    4
# Name: fea_1, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       1245.5
# 1       1277.0
# 2       1298.0
# 3       1335.5
# 4          NaN
#          ...
# 1120    1289.0
# 1121       NaN
# 1122    1220.0
# 1123    1250.0
# 1124    1415.0
# Name: fea_2, Length: 1125, dtype: float64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       3
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 1120    1
# 1121    2
# 1122    3
# 1123    3
# 1124    3
# Name: fea_3, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0        77000.0
# 1       113000.0
# 2       110000.0
# 3       151000.0
# 4        59000.0
#           ...
# 1120    173000.0
# 1121     50000.0
# 1122     76000.0
# 1123    137000.0
# 1124     93000.0
# Name: fea_4, Length: 1125, dtype: float64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1120    2
# 1121    2
# 1122    2
# 1123    2
# 1124    2
# Name: fea_5, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       15
# 1        8
# 2       11
# 3       11
# 4       11
#         ..
# 1120    15
# 1121    15
# 1122    11
# 1123     8
# 1124     8
# Name: fea_6, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       5
# 1      -1
# 2      -1
# 3       5
# 4       5
#        ..
# 1120    5
# 1121    5
# 1122    2
# 1123    5
# 1124    5
# Name: fea_7, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       109
# 1       100
# 2       101
# 3       110
# 4       108
#        ...
# 1120    112
# 1121    108
# 1122     90
# 1123     90
# 1124    113
# Name: fea_8, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       5
# 1       3
# 2       5
# 3       3
# 4       4
#        ..
# 1120    3
# 1121    4
# 1122    5
# 1123    5
# 1124    4
# Name: fea_9, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       151300
# 1       341759
# 2        72001
# 3        60084
# 4       450081
#          ...
# 1120    350702
# 1121    450000
# 1122     71002
# 1123     72000
# 1124    151300
# Name: fea_10, Length: 1125, dtype: int64>
#
# **********************************
# <bound method IndexOpsMixin.value_counts of 0       244.948974
# 1       207.173840
# 2         1.000000
# 3         1.000000
# 4       197.403141
#            ...
# 1120    200.000000
# 1121    169.000000
# 1122      1.000000
# 1123      1.000000
# 1124    273.861279
# Name: fea_11, Length: 1125, dtype: float64>
#
# **********************************

# %%
df.isnull().sum()
# Out:
# label       0
# id          0
# fea_1       0
# fea_2     149
# fea_3       0
# fea_4       0
# fea_5       0
# fea_6       0
# fea_7       0
# fea_8       0
# fea_9       0
# fea_10      0
# fea_11      0
# dtype: int64

# %% [markdown]
# ### Checking for Outliers

# %%
for i in df.columns:
    print('columns:',i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# columns: label
# columns: id
# columns: fea_1
# columns: fea_2
# columns: fea_3
# columns: fea_4
# columns: fea_5
# columns: fea_6
# columns: fea_7
# columns: fea_8
# columns: fea_9
# columns: fea_10
# columns: fea_11

# %% [markdown]
# ### Outliers were Identified

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot= True)
plt.show()

# %% [markdown]
# ### Imputing KNN Imputer

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
df['fea_2'] = impute.fit_transform(df[['fea_2']])

# %%
df.isnull().sum()
# Out:
# label     0
# id        0
# fea_1     0
# fea_2     0
# fea_3     0
# fea_4     0
# fea_5     0
# fea_6     0
# fea_7     0
# fea_8     0
# fea_9     0
# fea_10    0
# fea_11    0
# dtype: int64

# %%
df1
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date
# 0        16500.0  04/12/2016          0.0              NaN         NaN
# 1            NaN  04/12/2016     588720.0         491100.0         NaN
# 2            NaN  04/12/2016     840000.0         700500.0  22/04/2016
# 3        37400.0  03/12/2016       8425.2           7520.0  25/04/2016
# 4            NaN  03/12/2016      15147.6              NaN  26/04/2016
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaN          0.0              NaN         NaN
# 8246         NaN         NaN          0.0              NaN         NaN
# 8247         NaN         NaN      20654.4          33315.0         NaN
# 8248         NaN         NaN          0.0              NaN         NaN
# 8249         NaN         NaN     240000.0         200500.0         NaN
#
# [8250 rows x 12 columns]

# %%
cols = []
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
df['fea_2'] = impute.fit_transform(df[['fea_2']])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   object
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 773.6+ KB

# %% [markdown]
# ### Changing the data type of 'update_date' & 'report_date' columns

# %%
df1['update_date'] = pd.to_datetime(df1['update_date'],format="%d/%m/%Y")
print(df1['update_date'].dtype)
# Out:
# datetime64[ns]

# %%
df1['report_date'] = pd.to_datetime(df1['report_date'])

print(df1['report_date'].dtype)
# Out:
# datetime64[ns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   datetime64[ns]
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(7)
# memory usage: 773.6 KB

# %%
df1['year1'] = df1['report_date'].dt.year
df1['month2'] = df1['report_date'].dt.month
df1['day3'] = df1['report_date'].dt.day

# %%
df1['report_year1'] = df1['update_date'].dt.year
df1['report_month'] = df1['update_date'].dt.month
df1['report_day'] = df1['update_date'].dt.day

# %%
df1
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date  \
# 0        16500.0  2016-12-04          0.0              NaN         NaT
# 1            NaN  2016-12-04     588720.0         491100.0         NaT
# 2            NaN  2016-12-04     840000.0         700500.0  2016-04-22
# 3        37400.0  2016-12-03       8425.2           7520.0  2016-04-25
# 4            NaN  2016-12-03      15147.6              NaN  2016-04-26
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaT          0.0              NaN         NaT
# 8246         NaN         NaT          0.0              NaN         NaT
# 8247         NaN         NaT      20654.4          33315.0         NaT
# 8248         NaN         NaT          0.0              NaN         NaT
# 8249         NaN         NaT     240000.0         200500.0         NaT
#
#        year1  month2  day3  report_year1  report_month  report_day
# 0        NaN     NaN   NaN        2016.0          12.0         4.0
# 1        NaN     NaN   NaN        2016.0          12.0         4.0
# 2     2016.0     4.0  22.0        2016.0          12.0         4.0
# 3     2016.0     4.0  25.0        2016.0          12.0         3.0
# 4     2016.0     4.0  26.0        2016.0          12.0         3.0
# ...      ...     ...   ...           ...           ...         ...
# 8245     NaN     NaN   NaN           NaN           NaN         NaN
# 8246     NaN     NaN   NaN           NaN           NaN         NaN
# 8247     NaN     NaN   NaN           NaN           NaN         NaN
# 8248     NaN     NaN   NaN           NaN           NaN         NaN
# 8249     NaN     NaN   NaN           NaN           NaN         NaN
#
# [8250 rows x 18 columns]

# %% [markdown]
# ### Using KNN Imputer again

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['year1','month2','day3']
df1[cols] = df1[cols].round()
for i in cols:
    df1[i] = impute.fit_transform(df1[[i]])

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['report_year1','report_month','report_day']
df1[cols] = df1[cols].round()
for i in cols:
    df1[i] = impute.fit_transform(df1[[i]])

# %%
df1
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date  \
# 0        16500.0  2016-12-04          0.0              NaN         NaT
# 1            NaN  2016-12-04     588720.0         491100.0         NaT
# 2            NaN  2016-12-04     840000.0         700500.0  2016-04-22
# 3        37400.0  2016-12-03       8425.2           7520.0  2016-04-25
# 4            NaN  2016-12-03      15147.6              NaN  2016-04-26
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaT          0.0              NaN         NaT
# 8246         NaN         NaT          0.0              NaN         NaT
# 8247         NaN         NaT      20654.4          33315.0         NaT
# 8248         NaN         NaT          0.0              NaN         NaT
# 8249         NaN         NaT     240000.0         200500.0         NaT
#
#             year1    month2       day3  report_year1  report_month  report_day
# 0     2013.985706  6.241872  17.821469   2016.000000     12.000000    4.000000
# 1     2013.985706  6.241872  17.821469   2016.000000     12.000000    4.000000
# 2     2016.000000  4.000000  22.000000   2016.000000     12.000000    4.000000
# 3     2016.000000  4.000000  25.000000   2016.000000     12.000000    3.000000
# 4     2016.000000  4.000000  26.000000   2016.000000     12.000000    3.000000
# ...           ...       ...        ...           ...           ...         ...
# 8245  2013.985706  6.241872  17.821469   2011.617339      6.533074   15.176435
# 8246  2013.985706  6.241872  17.821469   2011.617339      6.533074   15.176435
# 8247  2013.985706  6.241872  17.821469   2011.617339      6.533074   15.176435
# 8248  2013.985706  6.241872  17.821469   2011.617339      6.533074   15.176435
# 8249  2013.985706  6.241872  17.821469   2011.617339      6.533074   15.176435
#
# [8250 rows x 18 columns]

# %%
df1.isnull().sum()
# Out:
# id                    0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# year1                 0
# month2                0
# day3                  0
# report_year1          0
# report_month          0
# report_day            0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   datetime64[ns]
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   datetime64[ns]
#  12  year1            8250 non-null   float64
#  13  month2           8250 non-null   float64
#  14  day3             8250 non-null   float64
#  15  report_year1     8250 non-null   float64
#  16  report_month     8250 non-null   float64
#  17  report_day       8250 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(7)
# memory usage: 1.1 MB

# %%
df1.prod_limit.value_counts()
# Out:
# 55000.0     103
# 11000.0      86
# 33000.0      51
# 27500.0      47
# 22000.0      46
#            ...
# 371800.0      1
# 321200.0      1
# 230175.0      1
# 35310.0       1
# 254100.0      1
# Name: prod_limit, Length: 321, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
cols = ['report_year1','report_month','report_day','year1','month2','day3']

for i in cols:
    df1[i] = df1[i].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   datetime64[ns]
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   datetime64[ns]
#  12  year1            8250 non-null   int32
#  13  month2           8250 non-null   int32
#  14  day3             8250 non-null   int32
#  15  report_year1     8250 non-null   int32
#  16  report_month     8250 non-null   int32
#  17  report_day       8250 non-null   int32
# dtypes: datetime64[ns](2), float64(3), int32(6), int64(7)
# memory usage: 966.9 KB

# %% [markdown]
# ### Merging both the datasets

# %%
df = pd.read_csv("customer_data.csv")
df1 = pd.read_csv("payment_data.csv")

merged_df = df.merge(df1, on='id')

# %%
merged_df.drop(columns=['update_date','report_date'],inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# label                 0
# id                    0
# fea_1                 0
# fea_2              1028
# fea_3                 0
# fea_4                 0
# fea_5                 0
# fea_6                 0
# fea_7                 0
# fea_8                 0
# fea_9                 0
# fea_10                0
# fea_11                0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# new_balance           0
# highest_balance     409
# dtype: int64

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['prod_limit','highest_balance','fea_2']
merged_df[cols] = merged_df[cols].round()
for i in cols:
    merged_df[i] = impute.fit_transform(merged_df[[i]])

# %%
corr_matrix = merged_df.corr()

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(20, 9))
plt.title("Correlation Heatmap", fontsize=16)

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr_matrix, mask=mask, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Splitting the data into train and test data

# %%
x = merged_df.drop(columns=['label'],axis=1)
y = merged_df['label']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size= 0.2)

# %% [markdown]
# ### Using Logistic and RandomForest Classifier

# %%
from sklearn.linear_model  import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

model1 = RandomForestClassifier(n_estimators = 310,n_jobs = -1,random_state = 15)
model1.fit(X_train, y_train)

y_pred = model.predict(X_test)
predictions = model1.predict(X_test)

# %% [markdown]
# ### metrics for models

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test,y_pred)
accuracy1 = accuracy_score(y_test,predictions)
print('logisticRegression:' )
print("Accuracy:", accuracy)
print()
print('RandomForestClassifier:' )
print("Accuracy:", accuracy1)
# Out:
# logisticRegression:
# Accuracy: 0.8515151515151516
#
# RandomForestClassifier:
# Accuracy: 0.9793939393939394

# %% [markdown]
# ### Accuracy of the model with X_test data

# %%
new_data_predictions_logistic = model.predict(X_test)

for i in range(15):
    predicted_label = new_data_predictions_logistic[i]
    actual_label = y_test.iloc[i]

    print("Instance", i+1)
    print("Predicted Label:", predicted_label)
    print("Actual Label:", actual_label)
    print("✅" if predicted_label == actual_label else "❌")
    print()
# Out:
# Instance 1
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 2
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 3
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 4
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 5
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 6
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 7
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 8
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 9
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 10
# Predicted Label: 0
# Actual Label: 1
# ❌
#
# Instance 11
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 12
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 13
# Predicted Label: 0
# Actual Label: 1
# ❌
#
# Instance 14
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 15
# Predicted Label: 0
# Actual Label: 1
# ❌

# %% [markdown]
# ### Accuracy of the model with X_test data

# %%
new_data_predictions_regeression = model1.predict(X_test)

for i in range(15):
    predicted_label = new_data_predictions_regeression[i]
    actual_label = y_test.iloc[i]

    print("Instance", i+1)
    print("Predicted Label:", predicted_label)
    print("Actual Label:", actual_label)
    print("✅" if predicted_label == actual_label else "❌")
    print()
# Out:
# Instance 1
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 2
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 3
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 4
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 5
# Predicted Label: 0
# Actual Label: 1
# ❌
#
# Instance 6
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 7
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 8
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 9
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 10
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 11
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 12
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 13
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 14
# Predicted Label: 0
# Actual Label: 0
# ✅
#
# Instance 15
# Predicted Label: 0
# Actual Label: 0
# ✅
